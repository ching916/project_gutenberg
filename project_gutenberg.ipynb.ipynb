# %%
# 匯入套件
from selenium import webdriver
from selenium.webdriver.common.by import By
from time import sleep
import requests
import os
import re

# ========== 設定儲存資料夾 ==========
folderPath = "homework_books"

# ========== 啟動瀏覽器 ==========
web_options = webdriver.ChromeOptions()
web_options.add_argument("--start-maximized")
web_options.add_argument("--incognito")
web_options.add_argument("--disable-popup-blocking")
web_options.add_argument("--disable-notifications")
web_options.add_argument("--lang=zh-TW")

driver = webdriver.Chrome(options=web_options)

# ========== 訪問網頁 ==========
def visit():
    driver.get("https://www.gutenberg.org/browse/languages/zh")

# ========== 爬取書籍連結 ==========
def parse():
    book = {}
    elements = driver.find_elements(By.CSS_SELECTOR, 'li.pgdbetext a[href]')
    for i in elements[:400]:
        title = i.text
        if re.match(r'[\u4e00-\u9fff，。！？、：「」『』（）《》〈〉—…；．·～]+', title) is None:
            continue
        href_attr = i.get_attribute('href')
        href_num = re.findall(r'\d+', href_attr)[0]
        href_target = f"https://www.gutenberg.org/cache/epub/{href_num}/pg{href_num}.txt"
        book.setdefault(title, href_target)
    return book

# ========== 存檔 ==========
def savetxt(title, content):
    safe_title = re.sub(r'[\\/:*?"<>|]', "_", title)
    if not os.path.exists(folderPath):
        os.makedirs(folderPath)
    file_path = f"{folderPath}/{safe_title}.txt"
    if os.path.exists(file_path):
        print(f"{safe_title}.txt 已存在，跳過保存")
    else:
        with open(file_path, "w", encoding="utf-8") as file:
            file.write(content)
            print(f"已儲存：{safe_title}.txt")

# ========== 關閉瀏覽器 ==========
def exit():
    global driver
    try:
        driver.quit()
    except Exception as e:
        print(f"關閉瀏覽器時錯誤：{e}")
    finally:
        print("瀏覽器已關閉")

# ========== 主程式 ==========
visit()
sleep(2)

books = parse()
print(f"共 {len(books)} 本書，開始下載...")

for idx, (title, url) in enumerate(books.items(), start=1):
    try:
        res = requests.get(url)
        res.encoding = 'utf-8'
        savetxt(title, res.text)
    except Exception as e:
        print(f"[{idx}] 下載失敗 {title}：{e}")

exit()
# Out:
# 共 316 本書，開始下載...
# 已儲存：豆棚閒話.txt
# 已儲存：戲中戲.txt
# 已儲存：比目魚.txt
# 已儲存：三字經.txt
# 已儲存：山水情.txt
# 已儲存：山海經.txt
# [7] 下載失敗 施公案：('Connection broken: IncompleteRead(1890833 bytes read, 1682751 more expected)', IncompleteRead(1890833 bytes read, 1682751 more expected))
# 已儲存：易經.txt
# 已儲存：木蘭奇女傳.txt
# 已儲存：海公案.txt
# 已儲存：燕丹子.txt
# 已儲存：狄公案.txt
# 已儲存：百家姓.txt
# 已儲存：禮記.txt
# 已儲存：綠牡丹.txt
# 已儲存：詩經.txt
# 已儲存：麟兒報.txt
# 已儲存：天豹圖.txt
# 已儲存：梁公九諫.txt
# 已儲存：長恨歌.txt
# 已儲存：李娃傳.txt
# 已儲存：玉樓春.txt
# 已儲存：漢書.txt
# 已儲存：引鳳蕭.txt
# 已儲存：今古奇觀.txt
# 已儲存：後西游記.txt
# 已儲存：飛跎全傳.txt
# 已儲存：佛說四十二章經.txt
# 已儲存：紅樓夢.txt
# 已儲存：洛神賦.txt
# 已儲存：晁氏儒言 一卷.txt
# 已儲存：水滸後傳.txt
# 已儲存：幼學瓊林.txt
# 已儲存：治世餘聞.txt
# 已儲存：琵琶記.txt
# 已儲存：雪月梅傳.txt
# 已儲存：龍川詞.txt
# 已儲存：三國志.txt
# [39] 下載失敗 隋唐演義：('Connection broken: IncompleteRead(1205393 bytes read, 660056 more expected)', IncompleteRead(1205393 bytes read, 660056 more expected))
# 已儲存：論語.txt
# 已儲存：滬語開路 = Conversational Exercises in the Shanghai Dialect.txt
# 已儲存：白圭志.txt
# 已儲存：孟子字義疏證.txt
# 已儲存：安樂集.txt
# 已儲存：鄧析子.txt
# 已儲存：醉醒石.txt
# 已儲存：唐鍾馗平鬼傳.txt
# 已儲存：春秋繁露.txt
# 已儲存：虬髯客傳.txt
# 已儲存：吳船錄.txt
# 已儲存：星槎勝覽.txt
# 已儲存：喻世明言.txt
# 已儲存：平妖傳.txt
# 已儲存：東周列國志.txt
# 已儲存：警世通言.txt
# 已儲存：醒世恆言.txt
# 已儲存：封氏聞見記.txt
# 已儲存：搜神記.txt
# 已儲存：搜神記 volume 11-14.txt
# 已儲存：搜神記 volume 1-3.txt
# 已儲存：搜神記 volume 15-17.txt
# 已儲存：搜神記 volume 18-20.txt
# 已儲存：搜神記 volume 4-10.txt
# 已儲存：抱朴子.txt
# 已儲存：西京雜記.txt
# 已儲存：幽明錄.txt
# 已儲存：明鏡公案.txt
# 已儲存：公孫龍子.txt
# 已儲存：竇娥冤.txt
# 已儲存：竇娥寃.txt
# 已儲存：管子.txt
# 已儲存：管子 — Volume 01 _ Chapters 1-5.txt
# 已儲存：管子 — Volume 02 _ Chapters 6-10.txt
# 已儲存：鬼谷子.txt
# 已儲存：穆天子传.txt
# 已儲存：漢武帝別國洞冥記.txt
# 已儲存：日知錄.txt
# 已儲存：海上花列傳.txt
# 已儲存：韩非子.txt
# 已儲存：風月夢.txt
# 已儲存：韓詩外傳.txt
# 已儲存：韓詩外傳, Complete.txt
# 已儲存：韓詩外傳, Vol. 1-2.txt
# 已儲存：韓詩外傳, Vol. 3-4.txt
# 已儲存：韓詩外傳, Vol. 5-6.txt
# 已儲存：韓詩外傳, Vol. 7-8.txt
# 已儲存：韓詩外傳, Vol. 9-10.txt
# 已儲存：唐诗三百首.txt
# 已儲存：長生殿.txt
# 已儲存：菜根譚.txt
# 已儲存：菜根譚前後集.txt
# 已儲存：筠州黃檗山斷際禪師傳法心要.txt
# 已儲存：山水小牘.txt
# 已儲存：高士傳.txt
# 已儲存：金剛般若波羅蜜經.txt
# 已儲存：天妃顯聖錄.txt
# 已儲存：三略.txt
# 已儲存：明夷待訪錄.txt
# 已儲存：鹽鐵論.txt
# 已儲存：一枕奇.txt
# 已儲存：六祖壇經.txt
# 已儲存：臺灣外紀.txt
# 已儲存：賈誼新書.txt
# 已儲存：金石緣.txt
# 已儲存：閱微草堂筆記.txt
# 已儲存：醒夢駢言.txt
# 已儲存：孔叢子.txt
# 已儲存：小爾雅.txt
# 已儲存：續世說.txt
# 已儲存：桃花扇.txt
# 已儲存：補紅樓夢.txt
# 已儲存：老子.txt
# 已儲存：道德經.txt
# [114] 下載失敗 臺灣通史
# 唐山過海的故事：[Errno 22] Invalid argument: 'homework_books/臺灣通史\n唐山過海的故事.txt'
# 已儲存：李太白集.txt
# 已儲存：官場現形記.txt
# 已儲存：文明小史.txt
# 已儲存：孫子算經.txt
# 已儲存：列子.txt
# 已儲存：脾胃論.txt
# 已儲存：李賀詩選.txt
# 已儲存：文心雕龍.txt
# 已儲存：二刻拍案惊奇.txt
# 已儲存：二刻拍案驚奇.txt
# 已儲存：初刻拍案驚奇.txt
# 已儲存：殺子報.txt
# 已儲存：西海紀遊草.txt
# 已儲存：漱玉詞.txt
# 已儲存：鏡花緣.txt
# 已儲存：李義山詩集.txt
# 已儲存：淮南子.txt
# 已儲存：老殘遊記.txt
# 已儲存：老殘遊記續集.txt
# 已儲存：海島算經.txt
# 已儲存：郁離子.txt
# 已儲存：人物志.txt
# 已儲存：隋唐嘉話.txt
# 已儲存：大唐新語.txt
# 已儲存：列仙傳.txt
# 已儲存：列女傳.txt
# 已儲存：新序.txt
# 已儲存：說苑.txt
# 已儲存：說苑, Volume 13-16.txt
# 已儲存：說苑, Volume 1-4.txt
# 已儲存：說苑, Volume 17-20.txt
# 已儲存：說苑, Volume 5-8.txt
# 已儲存：說苑, Volume 9-12.txt
# 已儲存：舊唐書.txt
# 已儲存：世說新語.txt
# 已儲存：樂章集.txt
# 已儲存：斬鬼傳.txt
# 已儲存：夢中緣.txt
# 已儲存：合錦回文傳.txt
# 已儲存：無聲戲.txt
# 已儲存：肉蒲團.txt
# 已儲存：閒情偶寄.txt
# 已儲存：闲情偶寄.txt
# 已儲存：弟子規.txt
# 已儲存：庚巳編.txt
# 已儲存：呻吟語.txt
# 已儲存：三國志演義.txt
# 已儲存：殘唐五代史演義傳.txt
# 已儲存：粉妝樓.txt
# 已儲存：粉妝樓1-10回.txt
# 已儲存：粉妝樓11-20回.txt
# 已儲存：粉妝樓21-30回.txt
# 已儲存：粉妝樓31-40回.txt
# 已儲存：粉妝樓41-50回.txt
# 已儲存：粉妝樓51-60回.txt
# 已儲存：粉妝樓61-70回.txt
# 已儲存：粉妝樓71-80回.txt
# 已儲存：粉妝樓全傳.txt
# 已儲存：說唐.txt
# 已儲存：常言道.txt
# 已儲存：大唐三藏取經詩話.txt
# 已儲存：六韜.txt
# 已儲存：癡人說夢記.txt
# 已儲存：封神演義.txt
# 已儲存：中國小說史略.txt
# 已儲存：南腔北調集.txt
# 已儲存：吶喊.txt
# 已儲存：徬徨.txt
# 已儲存：朝花夕拾.txt
# 已儲存：狂人日記.txt
# 已儲存：野草.txt
# 已儲存：阿Ｑ正傳.txt
# 已儲存：文子.txt
# 已儲存：老學庵筆記.txt
# 已儲存：茶經.txt
# 已儲存：近思錄.txt
# 已儲存：瀛涯勝覽.txt
# 已儲存：漢宮秋.txt
# 已儲存：孟子.txt
# 已儲存：東京夢華錄.txt
# 已儲存：白兔記.txt
# 已儲存：好逑傳.txt
# 已儲存：御製廣寒殿記.txt
# 已儲存：墨子.txt
# 已儲存：西湖佳話.txt
# 已儲存：癡人福.txt
# 已儲存：公墓.txt
# 已儲存：飲水詞集.txt
# 已儲存：春柳鶯.txt
# 已儲存：六一詞.txt
# 已儲存：歸田錄.txt
# 已儲存：蜀碧.txt
# 已儲存：九尾狐.txt
# 已儲存：聊齋志異.txt
# 已儲存：醒世姻緣.txt
# 已儲存：南部新書.txt
# 已儲存：東度記.txt
# 已儲存：金雲翹傳.txt
# 已儲存：拾遺記.txt
# 已儲存：負曝閒談.txt
# 已儲存：燕子箋.txt
# 已儲存：佛說無量壽經.txt
# 已儲存：蕉葉帕.txt
# 已儲存：商君書.txt
# 已儲存：商子.txt
# 已儲存：俗話傾談.txt
# 已儲存：慎子.txt
# 已儲存：浮生六記.txt
# 已儲存：枕中記.txt
# 已儲存：夢溪筆談.txt
# 已儲存：夢溪筆談, Volume 01-06.txt
# 已儲存：夢溪筆談, Volume 01-26.txt
# 已儲存：夢溪筆談, Volume 07-10.txt
# 已儲存：夢溪筆談, Volume 11-16.txt
# 已儲存：夢溪筆談, Volume 17-21.txt
# 已儲存：夢溪筆談, Volume 22-26.txt
# 已儲存：諧鐸.txt
# 已儲存：幽閨記.txt
# 已儲存：水滸傳.txt
# 已儲存：三俠五義.txt
# 已儲存：史記.txt
# 已儲存：司馬法.txt
# 已儲存：灵历集光.txt
# 已儲存：莊子的故事.txt
# 已儲存：天工開物.txt
# 已儲存：歸蓮夢.txt
# 已儲存：錦香亭.txt
# 已儲存：杜陽雜編.txt
# 已儲存：斷鴻零雁記.txt
# 已儲存：北夢瑣言.txt
# 已儲存：兵法 (Bīng Fǎ).txt
# 已儲存：孫子兵法.txt
# 已儲存：東坡志林.txt
# 已儲存：東坡樂府.txt
# 已儲存：水調歌頭.txt
# 已儲存：蘇洵集.txt
# 已儲存：孫子兵法道家新註解.txt
# 已儲存：牡丹亭.txt
# 已儲存：彭公案.txt
# 已儲存：五孝傳.txt
# 已儲存：搜神後記.txt
# 已儲存：搜神後記. Selections. 1985.txt
# 已儲存：轟天雷.txt
# 已儲存：人間樂.txt
# 已儲存：定情人.txt
# 已儲存：平山冷燕.txt
# 已儲存：玉嬌梨.txt
# 已儲存：玉支机.txt
# 已儲存：玉雙魚.txt
# 已儲存：畫圖緣.txt
# 已儲存：石點頭.txt
# 已儲存：商界現形記.txt
# 已儲存：玉蟾記.txt
# [268] 下載失敗 宋史：('Connection broken: IncompleteRead(3097296 bytes read, 11658248 more expected)', IncompleteRead(3097296 bytes read, 11658248 more expected))
# 已儲存：周髀算經.txt
# 已儲存：孔雀東南飛.txt
# 已儲存：孝經.txt
# 已儲存：春秋配.txt
# 已儲存：爾雅.txt
# 已儲存：竹書紀年.txt
# 已儲存：黄帝宅經.txt
# 已儲存：文淵閣四庫全書.txt
# 已儲存：本草備要.txt
# 已儲存：論衡.txt
# 已儲存：魏鄭公諫錄.txt
# 已儲存：人間詞話.txt
# 已儲存：海國春秋.txt
# 已儲存：冷眼观.txt
# 已儲存：竹齋集.txt
# 已儲存：西廂記.txt
# 已儲存：豔異編.txt
# 已儲存：分甘余話.txt
# 已儲存：劍俠傳.txt
# 已儲存：池北偶談.txt
# 已儲存：文中子中說.txt
# 已儲存：荀子集解.txt
# 已儲存：傳習錄.txt
# 已儲存：王陽明全集.txt
# 已儲存：故事新讀本_ 第一冊.txt
# 已儲存：花外集.txt
# 已儲存：圍爐夜話.txt
# 已儲存：尉繚子.txt
# 已儲存：花月痕.txt
# 已儲存：明月台.txt
# 已儲存：兒女英雄傳.txt
# 已儲存：玉壺淸話.txt
# 已儲存：西遊記.txt
# 已儲存：古文觀止.txt
# 已儲存：青箱雜記.txt
# 已儲存：海遊記.txt
# 已儲存：駐春園小史.txt
# 已儲存：九命奇冤.txt
# 已儲存：二十年目睹之怪現狀.txt
# 已儲存：恨海.txt
# 已儲存：情變.txt
# 已儲存：瞎騙奇聞.txt
# 已儲存：胡涂世界.txt
# 已儲存：貞觀政要.txt
# 已儲存：中國十大禁書之國色天香.txt
# 已儲存：儒林外史.txt
# 已儲存：楊家將.txt
# 已儲存：五色石.txt
# 瀏覽器已關閉
